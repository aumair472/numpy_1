# %%
# import numpy

# %%
import numpy as np

# %%
arr = np.array((2,5))

# %%
arr
# Out:
# array([2, 5])

# %%
arr2 = np.array([[10,20,30,40,50],[70,100, 120,150 ,200]])

# %%
arr2
# Out:
# array([[ 10,  20,  30,  40,  50],
#        [ 70, 100, 120, 150, 200]])

# %%
flat = arr2.flatten()

# %%
flat
# Out:
# array([ 10,  20,  30,  40,  50,  70, 100, 120, 150, 200])

# %%
flat[0]
# Out:
# np.int64(10)

# %%
flat[:3]
# Out:
# array([10, 20, 30])

# %%
flat[3:]
# Out:
# array([ 40,  50,  70, 100, 120, 150, 200])

# %%
flat[0:3]
# Out:
# array([10, 20, 30])

# %%
flat[-1]
# Out:
# np.int64(200)

# %%
idx = [0,2,4]

# %%
flat[idx]
# Out:
# array([10, 30, 50])

# %%
mask = flat > 50

# %%
flat[mask]
# Out:
# array([ 70, 100, 120, 150, 200])
